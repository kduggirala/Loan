# %%
import pandas as pd

# %%
df = pd.read_parquet("/Users/kdugg/Documents/2003Q3")

# %%
df
# Out:
#           LOAN_IDENTIFIER  MONTHLY_REPORTING  DELTA_INTEREST  LOAN_AGE  \
# 0            854403675290                 43         -0.8890       1.0
# 1            854403675290                 44         -0.7725       2.0
# 2            854403675290                 45         -0.5770       3.0
# 3            854403675290                 46         -0.5575       4.0
# 4            854403675290                 47         -0.5010       5.0
# ...                   ...                ...             ...       ...
# 102088875    811138027318                174          2.1390     132.0
# 102088876    811138027318                175          2.1275     133.0
# 102088877    811138027318                176          2.0675     134.0
# 102088878    811138027318                177          2.1650     135.0
# 102088879    811138027318                178          2.1875     136.0
#
#            ADJUSTED_MONTHS_TO_MATURITY  ORIGINAL_LOAN-TO-VALUE  \
# ...

# %%
df[df['ADJUSTED_MONTHS_TO_MATURITY']==-1]
# Out:
#           LOAN_IDENTIFIER  MONTHLY_REPORTING  DELTA_INTEREST  LOAN_AGE  \
# 1735         949191727380                100          0.3390      56.0
# 1736         949191727380                101          0.0550      57.0
# 1737         949191727380                102         -0.0510      58.0
# 1738         949191727380                103         -0.1025      59.0
# 1739         949191727380                104          0.3375      60.0
# ...                   ...                ...             ...       ...
# 102087370    974466443011                144         -1.9150     101.0
# 102087371    974466443011                145         -1.8900     102.0
# 102087372    974466443011                146         -1.9540     103.0
# 102087373    974466443011                147         -1.9100     104.0
# 102087374    974466443011                155         -1.3450     112.0
#
#            ADJUSTED_MONTHS_TO_MATURITY  ORIGINAL_LOAN-TO-VALUE  \
# ...

# %%
df[df['LOAN_IDENTIFIER']=='974466443011']
# Out:
#           LOAN_IDENTIFIER  MONTHLY_REPORTING  DELTA_INTEREST  LOAN_AGE  \
# 102087270    974466443011                 44         -1.0225       1.0
# 102087271    974466443011                 45         -0.8270       2.0
# 102087272    974466443011                 46         -0.8075       3.0
# 102087273    974466443011                 47         -0.7510       4.0
# 102087274    974466443011                 48         -0.5875       5.0
# ...                   ...                ...             ...       ...
# 102087371    974466443011                145         -1.8900     102.0
# 102087372    974466443011                146         -1.9540     103.0
# 102087373    974466443011                147         -1.9100     104.0
# 102087374    974466443011                155         -1.3450     112.0
# 102087375    974466443011                156         -1.4140     113.0
#
#            ADJUSTED_MONTHS_TO_MATURITY  ORIGINAL_LOAN-TO-VALUE  \
# ...

# %%
li1 = []
li2 = []
c = 0
for x in l:
    df123 = df[df['LOAN_IDENTIFIER'] == x]
    if len(df123[df123['ADJUSTED_MONTHS_TO_MATURITY'] == 0]) > 0:
        li1.append(x)
    else:
        li2.append(x)
    c += 1
    if c > 100:
        break

# %%
len(li1)

# %%
import fredapi

# %%
df[df['LOAN_IDENTIFIER'] == li2[0]]
